# %% [markdown]
# <!-- Customize the font and markdown size -->
# # Custom RL Algorithm with ev2gym gym environment🚗🚗🔋🔋📉
# ---
#
# This Notebook provides a simple example of how to develop your own custom RL environment using the OpenAI Gym interface. We will use the **simple configuration of ev2gym** for the power *setpoint tracking problem*. We will then train a simple DQN agent to solve the environment.

# %% [markdown]
# **Learning Objectives:**
# - Familiarize with the OpenAI Gym interface
# - Develop a DQN agent for a simple environment

# %% [markdown]
# ### 1. Creating the Environment 🚗

# %% [markdown]
# - ev2gym simulates a Charge Point Operator (CPO) controlling a **fixed number of charging stations** scattered in a city where EVs that arrive and depart.
#
# - The goal of the CPO is to **minimize the difference between the power setpoint and the actual power** consumed by the charging stations.
#
#  - The CPO can control the current(**A**) of each port of each charging station. The current is limited by the **maximum current**(**I**) of the charging station and the **maximum current**(**I**) of the port.

# %%
#Install the required packages
#!pip install ev2gym

# %%
import numpy as np
import pkg_resources

from ev2gym_driveway.models.ev2gym_driveway_env import EV2GymDriveway
from ev2gym_driveway.rl_agent.state import state_function_basic_profit_view
from ev2gym_driveway.rl_agent.reward import reward_function_profit_only

# we will use an example configuration file
config_file = "/example_config_files/3_houses_no_inflexible_loads.yaml"
config_file = pkg_resources.resource_filename('ev2gym_driveway', config_file)

# Creating the environment
env = EV2GymDriveway(config_file, seed=42, state_function=state_function_basic_profit_view,
        reward_function=reward_function_profit_only)
# Out:
# Warning: No trips found for EV 0 on Monday. Resampling...
# Warning: No trips found for EV 0 on Monday. Resampling...
# Warning: No trips found for EV 1 on Saturday. Resampling...
# Warning: No trips found for EV 2 on Wednesday. Resampling...
# Warning: No trips found for EV 2 on Saturday. Resampling...
# Warning: No trips found for EV 2 on Saturday. Resampling...

# %% [markdown]
# #### 1.1 Action Space
# The ***action space*** is a vector of size **N** (total number of ports) where each element is a continuous value between **-1** and **1** representing the **percentage of the maximum current** that the CPO wants to set for each
# port.
#
# Values from -1 to 0 represent discharging the EVs, 0 means no current, and values from 0 to 1 represent charging the EVs.
#
#
# **Discretization** is necessary because the action space is continuous and the DQN algorithm requires a discrete action space

# %%
# Example discretization of the state space
def example_discretize_action(action):
    if action == 0:
        return [0, 0]
    elif action == 1:
        return [0.5, 0]
    elif action == 2:
        return [1, 0]
    elif action == 3:
        return [0, 0.5]
    elif action == 4:
        return [0, 1]
    elif action == 5:
        return [0.5, 0.5]    
    else:
        raise ValueError("Invalid action: ", action)
    
n_actions = 6

# %% [markdown]
# #### Your turn: **Create the discretized action space**
# - It should be a list of two ints from [0 to 1]
# - Use the same format as in the example above
# - Do not forget to put the number of different actions in the **n_actions** variable

# %%
# Example: Make your own discretization of the action space
def discretize_action(action):
    if 0 <= action and action < 41**3:
        ev0 = action // 41**2
        ev1 = (action % 41**2) // 41
        ev2 = action % 41
        return [-1.0 + 0.05 * ev0, -1.0 + 0.05 * ev1, -1.0 + 0.05 * ev2]
    else:
        raise ValueError("Invalid action: ", action)    
    
n_actions = 41**3

# %% [markdown]
# #### 1.2 State Space
#
# The ***state space*** provides information about the current state of the environment. Normaly the user has the option to configure the state space. In this case, the state space is a vector of 14 variables where each element is a continuous value representing the following information:
#
# - **[0-3]**: Time of the simulation
# - **[4]**: Power Setpoint for the current timestep
# - **[5]**: Total power potential of the charging stations, if EVs were charging at maximum current
# - **[6-10]**: Information about EV at Charging Station 1
# - **[11-14]**: Information about EV at Charging Station 2

# %%
#Get the initial state
env.reset()[0] #cutting off the extra {}
# Out:
# Warning: No trips found for EV 0 on Monday. Resampling...
# Warning: No trips found for EV 0 on Saturday. Resampling...
# Warning: No trips found for EV 1 on Monday. Resampling...
# Warning: No trips found for EV 1 on Friday. Resampling...
# Warning: No trips found for EV 1 on Sunday. Resampling...
# Warning: No trips found for EV 2 on Thursday. Resampling...
# Warning: No trips found for EV 2 on Saturday. Resampling...
# Warning: No trips found for EV 2 on Sunday. Resampling...
# array([ 0.62608696, -0.2019    ,  0.2019    ,  0.96592583,  0.25881905,
#         0.90434783, -0.2019    ,  0.2019    ,  0.96592583,  0.25881905,
#         0.46956522, -0.2019    ,  0.2019    ,  0.96592583,  0.25881905])

# %% [markdown]
# #### 1.3 Reward Function
#
# The ***reward function*** returns a reward value based on action that led to the current state of the environment. The reward function is defined by the user and it is one of the most important parts of the environment. The reward function should be designed to guide the agent to the desired behavior.
#
# ! The reward function is **called in every step** of the simultion.

# %% [markdown]
# Example reward function that penalizes the squared difference between the minimum of the power setpoint or the power potential and the actual power consumed by the charging stations.
#
# $$
# R(s_t,a_t,s_{t+1}) = - (min(P^{setpoint}, P^{potential}) - P^{actual})^2
# $$

# %%
def example_reward_function(env,*args):
    # This reward function is the squared tracking error that uses the minimum of the power setpoints and the charge power potential
    # The reward is negative
    
    reward = - (min(env.power_setpoints[env.current_step-1], env.charge_power_potential[env.current_step-1]) -
        env.current_power_usage[env.current_step-1])**2
    
    return reward

# %% [markdown]
# #### Your turn: **Create the reward function**
# - It should be a function that returns a float
# - Use the same format as in the example above
#
# - Available variables:
#     - **env.current_step**: current timestep
#     - **env.power_setpoints[]**: list of power setpoints for each timestep
#     - **env.charge_power_potential[]**: list of total power potential for each timestep
#     - **env.current_power_usage[]**: list of actual power charged at each timestep
#     - ...

# %%
def reward_function(env,*args):
    
    reward = reward_function_profit_only(env, None, None, None)
    
    # your code here
    
    return reward

# %% [markdown]
# ## 2. Setting Up the DQN Agent 🤖
# ---
#
# Here, we will develop a simple DQN agent to solve the environment.
#
# Code based on the [DQN tutorial](https://pytorch.org/tutorials/intermediate/reinforcement_q_learning.html) from the PyTorch website.
#
# ![image.png](attachment:image.png)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import random
import math
from collections import namedtuple, deque
from itertools import count

#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device("mps" if torch.mps.is_available() else "cpu")

# %%
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))

class ReplayMemory(object):

    def __init__(self, capacity):
        self.memory = deque([], maxlen=capacity)

    def push(self, *args):
        """Save a transition"""
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %% [markdown]
# ##### Neural Network Architecture
#
# In RL, the neural network is usually a simple fully connected network with 2 hidden layers. The input is the state space and the output is the action space.

# %%
class Example_Qnetwork(nn.Module):

    def __init__(self, n_observations, n_actions):
        super(Example_Qnetwork, self).__init__()
        self.layer1 = nn.Linear(n_observations, 128)
        self.layer2 = nn.Linear(128, 128)
        self.layer3 = nn.Linear(128, n_actions)

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        return self.layer3(x)

# %% [markdown]
# ##### Design Your own Q-network
#
# - Based on the example above, design your own Q-network
#     - Number of hidden layers
#     - Number of neurons in each layer
#     - Activation functions

# %%
class Qnetwork(nn.Module):

    def __init__(self, n_observations, n_actions):
        super(Qnetwork, self).__init__()
        # your code here

    def forward(self, x):
        # your code here

        return # your code here

# %% [markdown]
# #### Training
#
# In an RL training process the agent interacts with the environment and learns from the experience. The agent's experience is stored in a replay memory. The agent samples a batch of experiences from the replay memory and learns from it. The goal is to maximize the expected reward.

# %%
# BATCH_SIZE is the number of transitions sampled from the replay buffer
# GAMMA is the discount factor as mentioned in the previous section
# EPS_START is the starting value of epsilon
# EPS_END is the final value of epsilon
# EPS_DECAY controls the rate of exponential decay of epsilon, higher means a slower decay
# TAU is the update rate of the target network
# LR is the learning rate of the ``AdamW`` optimizer
BATCH_SIZE = 64
GAMMA = 0.99
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 200
TAU = 0.005
LR = 1e-4


# Get the number of state observations
state,_ = env.reset()
n_observations = len(state)

policy_net = Example_Qnetwork(n_observations, n_actions).to(device)
target_net = Example_Qnetwork(n_observations, n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())

optimizer = optim.AdamW(policy_net.parameters(), lr=LR, amsgrad=True)
memory = ReplayMemory(10000)

steps_done = 0
# Out:
# Warning: No trips found for EV 0 on Thursday. Resampling...
# Warning: No trips found for EV 0 on Thursday. Resampling...
# Warning: No trips found for EV 0 on Friday. Resampling...
# Warning: No trips found for EV 0 on Sunday. Resampling...
# Warning: No trips found for EV 0 on Sunday. Resampling...
# Warning: No trips found for EV 1 on Thursday. Resampling...

# %% [markdown]
# #### Exploration
#
# The agent uses an $\epsilon$-greedy policy to explore the environment. The $\epsilon$-greedy policy selects a random action with probability $\epsilon$ and the action with the highest Q-value with probability $1-\epsilon$.

# %%
def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max(1) will return the largest column value of each row.
            # second column on max result is index of where max element was
            # found, so we pick action with the larger expected reward.
            return policy_net(state).max(1).indices.view(1, 1)
    else:
        return torch.tensor([[random.randint(0,n_actions-1)]], device=device, dtype=torch.long)

# %% [markdown]
# #### Update Neural Network
#
# The neural network is updated using the DQN loss function:
#
# $$
# L = \frac{1}{N}\sum_i (y_i - Q(s_i, a_i))^2
# $$
#
# where $y_i$ is the target value and $Q(s_i, a_i)$ is the predicted value.
#
# The target value is calculated as follows:
#
# $$
# y_i = r_i + \gamma \max_{a'} Q(s_{i+1}, a')
#
# $$
#
# where $r_i$ is the reward, $\gamma$ is the discount factor, and $s_{i+1}$ is the next state.
#
# #### Target Network
#
# The target network is used to calculate the target value. The weights of the target network are updated with the weights of the Q-network every $C$ steps.

# %%
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)
    # Transpose the batch (see https://stackoverflow.com/a/19343/3343043 for
    # detailed explanation). This converts batch-array of Transitions
    # to Transition of batch-arrays.
    batch = Transition(*zip(*transitions))

    # Compute a mask of non-final states and concatenate the batch elements
    # (a final state would've been the one after which simulation ended)
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
    # columns of actions taken. These are the actions which would've been taken
    # for each batch state according to policy_net
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # Compute V(s_{t+1}) for all next states.
    # Expected values of actions for non_final_next_states are computed based
    # on the "older" target_net; selecting their best reward with max(1).values
    # This is merged based on the mask, such that we'll have either the expected
    # state value or 0 in case the state was final.
    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    
    with torch.no_grad():
        next_state_values[non_final_mask] = target_net(non_final_next_states).max(1).values
    # Compute the expected Q values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Compute Huber loss
    criterion = nn.SmoothL1Loss()
    loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))

    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    # In-place gradient clipping
    torch.nn.utils.clip_grad_value_(policy_net.parameters(), 100)
    optimizer.step()

# %% [markdown]
# #### Main Training Loop

# %%
episode_rewards = []
episode_stats = []

env.set_reward_function(reward_function)

if torch.cuda.is_available():
    num_episodes = 200
elif torch.mps.is_available():
    num_episodes = 200
else:
    num_episodes = 50
    
    

for i_episode in range(num_episodes):
    # Initialize the environment and get it's state
    state, _ = env.reset()
    state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
    
    episode_reward = 0
    for t in count():
        action = select_action(state)    
        
        observation, reward, done, truncated, stats = env.step(discretize_action(action.item()))
        episode_reward += reward
        reward = torch.tensor([reward], dtype=torch.float32, device=device)        

        if done:
            next_state = None
        else:
            next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)

        # Store the transition in memory
        memory.push(state, action, next_state, reward)

        # Move to the next state
        state = next_state

        # Perform one step of the optimization (on the policy network)
        optimize_model()

        # Soft update of the target network's weights
        # θ′ ← τ θ + (1 −τ )θ′
        target_net_state_dict = target_net.state_dict()
        policy_net_state_dict = policy_net.state_dict()
        for key in policy_net_state_dict:
            target_net_state_dict[key] = policy_net_state_dict[key]*TAU + target_net_state_dict[key]*(1-TAU)
        target_net.load_state_dict(target_net_state_dict)

        if done:
            episode_rewards.append(episode_reward)
            episode_stats.append(stats)
            print(f'Iteration {i_episode}/{num_episodes}: Episode reward: {episode_reward} ')
            # episode_durations.append(t + 1)
            # plot_durations()
            
            break

print('Complete')
# plot_durations(show_result=True)
# plt.ioff()
# plt.show()
# Out:
# Warning: No trips found for EV 0 on Tuesday. Resampling...
# Warning: No trips found for EV 0 on Thursday. Resampling...
# Warning: No trips found for EV 0 on Sunday. Resampling...
# Warning: No trips found for EV 1 on Monday. Resampling...
# Warning: No trips found for EV 1 on Tuesday. Resampling...
# Warning: No trips found for EV 2 on Monday. Resampling...
# Warning: No trips found for EV 2 on Monday. Resampling...
# Warning: No trips found for EV 2 on Thursday. Resampling...
# EV 0 arrived from trip at 2022-01-17 09:45:00. Drove: 3.0986546426351786 km.
# EV 0 used 0.42 kWh of energy during the trip.
# Energy Before Trip: 52.51 kWh
# Energy After Trip: 52.09 kWh
# EV 0 arrived from trip at 2022-01-17 12:15:00. Drove: 12.994745357364822 km.
# EV 0 used 1.78 kWh of energy during the trip.
# Energy Before Trip: 56.61 kWh
# Energy After Trip: 54.83 kWh
# EV 0 arrived from trip at 2022-01-17 21:30:00. Drove: 34.26523910503414 km.
# EV 0 used 5.62 kWh of energy during the trip.
# Energy Before Trip: 40.18 kWh
# Energy After Trip: 34.56 kWh
# EV 0 arrived from trip at 2022-01-17 21:45:00. Drove: 7.453574692355502 km.
# EV 0 used 1.02 kWh of energy during the trip.
# Energy Before Trip: 31.07 kWh
# Energy After Trip: 30.05 kWh
# EV 0 arrived from trip at 2022-01-18 11:00:00. Drove: 6.771430577998763 km.
# EV 0 used 0.93 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 9.07 kWh
# EV 0 arrived from trip at 2022-01-18 16:30:00. Drove: 5.340128191423247 km.
# EV 0 used 0.73 kWh of energy during the trip.
# Energy Before Trip: 55.85 kWh
# Energy After Trip: 55.12 kWh
# EV 0 arrived from trip at 2022-01-18 18:45:00. Drove: 65.8599140087011 km.
# EV 0 used 10.80 kWh of energy during the trip.
# Energy Before Trip: 48.27 kWh
# Energy After Trip: 37.47 kWh
# EV 0 arrived from trip at 2022-01-19 13:15:00. Drove: 3.7207860783095064 km.
# EV 0 used 0.51 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 9.49 kWh
# EV 0 arrived from trip at 2022-01-19 18:15:00. Drove: 52.981193163455615 km.
# EV 0 used 7.26 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 50.24 kWh
# EV 0 arrived from trip at 2022-01-19 18:15:00. Drove: 67.05016546923562 km.
# EV 0 used 11.00 kWh of energy during the trip.
# Energy Before Trip: 52.81 kWh
# Energy After Trip: 41.81 kWh
# EV 0 arrived from trip at 2022-01-20 12:00:00. Drove: 12.326604201367308 km.
# EV 0 used 1.69 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 8.31 kWh
# EV 0 arrived from trip at 2022-01-20 15:45:00. Drove: 26.764654481044122 km.
# EV 0 used 3.67 kWh of energy during the trip.
# Energy Before Trip: 57.49 kWh
# Energy After Trip: 53.82 kWh
# EV 0 arrived from trip at 2022-01-20 17:45:00. Drove: 16.208424300807973 km.
# EV 0 used 2.22 kWh of energy during the trip.
# Energy Before Trip: 53.59 kWh
# Energy After Trip: 51.37 kWh
# EV 0 arrived from trip at 2022-01-20 20:15:00. Drove: 35.710544449968914 km.
# EV 0 used 5.86 kWh of energy during the trip.
# Energy Before Trip: 52.59 kWh
# Energy After Trip: 46.73 kWh
# EV 0 arrived from trip at 2022-01-21 16:00:00. Drove: 18.174839738968316 km.
# EV 0 used 2.49 kWh of energy during the trip.
# Energy Before Trip: 56.34 kWh
# Energy After Trip: 53.85 kWh
# EV 0 arrived from trip at 2022-01-21 17:45:00. Drove: 84.92294139216894 km.
# EV 0 used 11.63 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: -1.63 kWh
# EV 0 arrived from trip at 2022-01-21 20:15:00. Drove: 59.28052400248587 km.
# EV 0 used 9.72 kWh of energy during the trip.
# Energy Before Trip: 54.44 kWh
# Energy After Trip: 44.72 kWh
# EV 0 arrived from trip at 2022-01-22 13:00:00. Drove: 15.270226090739591 km.
# EV 0 used 2.09 kWh of energy during the trip.
# Energy Before Trip: 55.03 kWh
# Energy After Trip: 52.94 kWh
# EV 0 arrived from trip at 2022-01-22 16:30:00. Drove: 1.2492639279055362 km.
# EV 0 used 0.17 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 9.83 kWh
# EV 0 arrived from trip at 2022-01-22 16:45:00. Drove: 81.17915045369794 km.
# EV 0 used 13.31 kWh of energy during the trip.
# Energy Before Trip: 57.46 kWh
# Energy After Trip: 44.15 kWh
# EV 0 arrived from trip at 2022-01-22 21:00:00. Drove: 16.600507134866437 km.
# EV 0 used 2.27 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 7.73 kWh
# EV 0 arrived from trip at 2022-01-23 10:30:00. Drove: 49.483454207582284 km.
# EV 0 used 8.12 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 49.38 kWh
# EV 0 arrived from trip at 2022-01-23 16:15:00. Drove: 2.740578993163458 km.
# EV 0 used 0.38 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 9.62 kWh
# EV 0 arrived from trip at 2022-01-23 17:30:00. Drove: 38.88921599751397 km.
# EV 0 used 5.33 kWh of energy during the trip.
# Energy Before Trip: 57.47 kWh
# Energy After Trip: 52.14 kWh
# EV 0 arrived from trip at 2022-01-23 22:00:00. Drove: 8.699837986326916 km.
# EV 0 used 1.19 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 8.81 kWh
# total_energy_charged: 573.6734377136756
# total_energy_discharged: 475.378767716213
# total_money_spent_charging: -111.70841192247309
# total_money_earned_discharging: 93.01530871798712
# total_transformer_overload: 0.0
# total_reward: 96722.14889122157
# Iteration 0/200: Episode reward: 96722.14889122157
# Warning: No trips found for EV 0 on Wednesday. Resampling...
# Warning: No trips found for EV 0 on Friday. Resampling...
# Warning: No trips found for EV 0 on Friday. Resampling...
# Warning: No trips found for EV
kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 46.38 kWh
# EV 0 arrived from trip at 2022-01-23 20:15:00. Drove: 2.9536240024860136 km.
# EV 0 used 0.40 kWh of energy during the trip.
# Energy Before Trip: 55.11 kWh
# Energy After Trip: 54.71 kWh
# EV 0 arrived from trip at 2022-01-23 20:45:00. Drove: 3.153666264760716 km.
# EV 0 used 0.43 kWh of energy during the trip.
# Energy Before Trip: 56.53 kWh
# Energy After Trip: 56.10 kWh
# total_energy_charged: 254.04375295344624
# total_energy_discharged: 190.12322409155064
# total_money_spent_charging: -48.49508837062041
# total_money_earned_discharging: 37.771390394866785
# total_transformer_overload: 0.0
# total_reward: 36492.40207961122
# Iteration 3/200: Episode reward: 36492.40207961122
# Warning: No trips found for EV 0 on Monday. Resampling...
# Warning: No trips found for EV 0 on Friday. Resampling...
# Warning: No trips found for EV 0 on Sunday. Resampling...
# Warning: No trips found for EV 0 on Sunday. Resampling...
# Warning: No trips found for EV 1 on Thursday. Resampling...
# Warning: No trips found for EV 1 on Thursday. Resampling...
# Warning: No trips found for EV 2 on Tuesday. Resampling...
# Warning: No trips found for EV 2 on Sunday. Resampling...
# Warning: No trips found for EV 2 on Sunday. Resampling...
# EV 0 arrived from trip at 2022-01-17 14:45:00. Drove: 20.104247358607818 km.
# EV 0 used 2.75 kWh of energy during the trip.
# Energy Before Trip: 50.51 kWh
# Energy After Trip: 47.76 kWh
# EV 0 arrived from trip at 2022-01-17 15:45:00. Drove: 12.075551162212555 km.
# EV 0 used 1.65 kWh of energy during the trip.
# Energy Before Trip: 30.00 kWh
# Energy After Trip: 28.35 kWh
# EV 0 arrived from trip at 2022-01-17 20:30:00. Drove: 18.55091919204475 km.
# EV 0 used 3.04 kWh of energy during the trip.
# Energy Before Trip: 44.36 kWh
# Energy After Trip: 41.32 kWh
# EV 0 arrived from trip at 2022-01-18 11:00:00. Drove: 20.228273561218145 km.
# EV 0 used 2.77 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 7.23 kWh
# EV 0 arrived from trip at 2022-01-18 14:30:00. Drove: 54.95461008079562 km.
# EV 0 used 9.01 kWh of energy during the trip.
# Energy Before Trip: 56.94 kWh
# Energy After Trip: 47.93 kWh
# EV 0 arrived from trip at 2022-01-18 15:30:00. Drove: 27.807874878806714 km.
# EV 0 used 3.81 kWh of energy during the trip.
# Energy Before Trip: 48.64 kWh
# Energy After Trip: 44.83 kWh
# EV 0 arrived from trip at 2022-01-18 17:15:00. Drove: 17.43868421379738 km.
# EV 0 used 2.39 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 7.61 kWh
# EV 0 arrived from trip at 2022-01-19 12:45:00. Drove: 11.0193280174021 km.
# EV 0 used 1.51 kWh of energy during the trip.
# Energy Before Trip: 53.18 kWh
# Energy After Trip: 51.67 kWh
# EV 0 arrived from trip at 2022-01-19 13:30:00. Drove: 58.33732473586065 km.
# EV 0 used 7.99 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 2.01 kWh
# EV 0 arrived from trip at 2022-01-19 16:15:00. Drove: 4.9210396519577415 km.
# EV 0 used 0.67 kWh of energy during the trip.
# Energy Before Trip: 49.03 kWh
# Energy After Trip: 48.36 kWh
# EV 0 arrived from trip at 2022-01-19 18:00:00. Drove: 3.542748464885009 km.
# EV 0 used 0.58 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 56.92 kWh
# EV 0 arrived from trip at 2022-01-20 11:30:00. Drove: 10.630245817277803 km.
# EV 0 used 1.74 kWh of energy during the trip.
# Energy Before Trip: 52.17 kWh
# Energy After Trip: 50.43 kWh
# EV 0 arrived from trip at 2022-01-20 16:30:00. Drove: 222.50600811684282 km.
# EV 0 used 30.48 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip:
. Resampling...
# Warning: No trips found for EV 1 on Sunday. Resampling...
# Warning: No trips found for EV 1 on Sunday. Resampling...
# EV 0 arrived from trip at 2022-01-17 13:30:00. Drove: 4.751003729024242 km.
# EV 0 used 0.65 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 9.35 kWh
# EV 0 arrived from trip at 2022-01-17 15:45:00. Drove: 16.898570105655704 km.
# EV 0 used 2.77 kWh of energy during the trip.
# Energy Before Trip: 15.09 kWh
# Energy After Trip: 12.32 kWh
# EV 0 arrived from trip at 2022-01-17 17:30:00. Drove: 9.740057750155383 km.
# EV 0 used 1.33 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 56.17 kWh
# EV 0 arrived from trip at 2022-01-18 11:45:00. Drove: 6.244319216904907 km.
# EV 0 used 0.86 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 9.14 kWh
# EV 0 arrived from trip at 2022-01-18 12:30:00. Drove: 8.232739303915467 km.
# EV 0 used 1.35 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 56.15 kWh
# EV 0 arrived from trip at 2022-01-18 14:45:00. Drove: 15.802338508390303 km.
# EV 0 used 2.16 kWh of energy during the trip.
# Energy Before Trip: 53.56 kWh
# Energy After Trip: 51.40 kWh
# EV 0 arrived from trip at 2022-01-18 15:45:00. Drove: 6.072282871348665 km.
# EV 0 used 1.00 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 56.50 kWh
# EV 0 arrived from trip at 2022-01-18 21:15:00. Drove: 0.9902091982597888 km.
# EV 0 used 0.16 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 57.34 kWh
# EV 0 arrived from trip at 2022-01-19 14:30:00. Drove: 368.74990458670015 km.
# EV 0 used 50.52 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: -40.52 kWh
# EV 0 arrived from trip at 2022-01-19 16:45:00. Drove: 24.955272218769423 km.
# EV 0 used 3.42 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 54.08 kWh
# EV 0 arrived from trip at 2022-01-19 18:00:00. Drove: 30.47443823492852 km.
# EV 0 used 5.00 kWh of energy during the trip.
# Energy Before Trip: 52.70 kWh
# Energy After Trip: 47.70 kWh
# EV 0 arrived from trip at 2022-01-19 22:00:00. Drove: 29.868310180236165 km.
# EV 0 used 4.90 kWh of energy during the trip.
# Energy Before Trip: 57.34 kWh
# Energy After Trip: 52.44 kWh
# EV 0 arrived from trip at 2022-01-20 10:45:00. Drove: 36.79177287756361 km.
# EV 0 used 6.03 kWh of energy during the trip.
# Energy Before Trip: 50.78 kWh
# Energy After Trip: 44.75 kWh
# EV 0 arrived from trip at 2022-01-20 16:30:00. Drove: 222.50600811684282 km.
# EV 0 used 30.48 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: -20.48 kWh
# EV 0 arrived from trip at 2022-01-20 20:15:00. Drove: 10.059125158483527 km.
# EV 0 used 1.38 kWh of energy during the trip.
# Energy Before Trip: 57.42 kWh
# Energy After Trip: 56.04 kWh
# EV 0 arrived from trip at 2022-01-21 18:00:00. Drove: 70.21183342448722 km.
# EV 0 used 9.62 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 0.38 kWh
# EV 0 arrived from trip at 2022-01-21 20:15:00. Drove: 0.780164822871346 km.
# EV 0 used 0.11 kWh of energy during the trip.
# Energy Before Trip: 57.05 kWh
# Energy After Trip: 56.94 kWh
# EV 0 arrived from trip at 2022-01-21 20:30:00. Drove: 4.033852218769421 km.
# EV 0 used 0.66 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 56.84 kWh
# EV 0 arrived from trip at 2022-01-22 11:30:00. Drove: 3.6687750901180904 km.
# EV 0 used 0.50 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 9.50 kWh
# EV 0 arrived from trip at 2022-01-22 15:00:00. Drove: 62.29916174021125 km.
# EV 0 used 10.22 kWh of energy during the trip.
# Energy Before Trip: 44.79 kWh
# Energy After Trip: 34.57 kWh
# EV 0 arrived from trip at 2022-01-22 23:30:00. Drove: 15.419257576134243 km.
# EV 0 used 2.11 kWh of energy during the trip.
# Energy Before Trip: 54.14 kWh
# Energy After Trip: 52.03 kWh
# EV 0 arrived from trip at 2022-01-23 15:15:00. Drove: 41.180700111870735 km.
# EV 0 used 5.64 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 51.86 kWh
# EV 0 arrived from trip at 2022-01-23 18:00:00. Drove: 126.51872919825972 km.
# EV 0 used 17.33 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: -7.33 kWh
# EV 0 arrived from trip at 2022-01-23 18:00:00. Drove: 67.8103260658794 km.
# EV 0 used 11.12 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 46.38 kWh
# EV 0 arrived from trip at 2022-01-23 23:15:00. Drove: 38.498133374767015 km.
# EV 0 used 5.27 kWh of energy during the trip.
# Energy Before Trip: 50.90 kWh
# Energy After Trip: 45.63 kWh
# total_energy_charged: 269.8332981208437
# total_energy_discharged: 194.6789578090246
# total_money_spent_charging: -51.41686902719585
# total_money_earned_discharging: 37.828633399265556
# total_transformer_overload: 0.0
# total_reward: 36811.89698111605
# Iteration 6/200: Episode reward: 36811.89698111605
# Warning: No trips found for EV 0 on Monday. Resampling...
# Warning: No trips found for EV 0 on Wednesday. Resampling...
# Warning: No trips found for EV 0 on Saturday. Resampling...
# Warning: No trips found for EV 1 on Wednesday. Resampling...
# Warning: No trips found for EV 1 on Saturday. Resampling...
# Warning: No trips found for EV 1 on Sunday. Resampling...
# Warning: No trips found for EV 2 on Wednesday. Resampling...
# Warning: No trips found for EV 2 on Wednesday. Resampling...
# Warning: No trips found for EV 2 on Wednesday. Resampling...
# Warning: No trips found for EV 2 on Thursday. Resampling...
# Warning: No trips found for EV 2 on Sunday. Resampling...
# Warning: No trips found for EV 2 on Sunday. Resampling...
# EV 0 arrived from trip at 2022-01-17 11:00:00. Drove: 51.29583710379114 km.
# EV 0 used 8.41 kWh of energy during the trip.
# Energy Before Trip: 25.72 kWh
# Energy After Trip: 17.31 kWh
# EV 0 arrived from trip at 2022-01-17 13:30:00. Drove: 4.751003729024242 km.
# EV 0 used 0.65 kWh of energy during the trip.
# Energy Before Trip: 12.48 kWh
# Energy After Trip: 11.83 kWh
# EV 0 arrived from trip at 2022-01-17 17:30:00. Drove: 20.223272504661278 km.
# EV 0 used 3.32 kWh of energy during the trip.
# Energy Before Trip: 57.18 kWh
# Energy After Trip: 53.86 kWh
# EV 0 arrived from trip at 2022-01-17 18:45:00. Drove: 30.958540509633295 km.
# EV 0 used 4.24 kWh of energy during the trip.
# Energy Before Trip: 54.56 kWh
# Energy After Trip: 50.32 kWh
# EV 0 arrived from trip at 2022-01-18 11:45:00. Drove: 6.244319216904907 km.
# EV 0 used 0.86 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 9.14 kWh
# EV 0 arrived from trip at 2022-01-18 17:00:00. Drove: 11.011326326911124 km.
# EV 0 used 1.51 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 55.99 kWh
# EV 0 arrived from trip at 2022-01-18 19:15:00. Drove: 113.43796566811682 km.
# EV 0 used 18.60 kWh of energy during the trip.
# Energy Before Trip: 52.70 kWh
# Energy After Trip: 34.10 kWh
# EV 0 arrived from trip at 2022-01-19 08:30:00. Drove: 19.877199390925984 km.
# EV 0 used 2.72 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 54.78 kWh
# EV 0 arrived from trip at 2022-01-19 15:00:00. Drove: 9.965105295214412 km.
# EV 0 used 1.63 kWh of energy during the trip.
# Energy Before Trip: 49.98 kWh
# Energy After Trip: 48.35 kWh
# EV 0 arrived from trip at 2022-01-19 15:30:00. Drove: 35.82256811684284 km.
# EV 0 used 4.91 kWh of energy during the trip.
# Energy Before Trip: 56.54 kWh
# Energy After Trip: 51.63 kWh
# EV 0 arrived from trip at 2022-01-19 16:15:00. Drove: 8.471789807333748 km.
# EV 0 used 1.16 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 8.84 kWh
# EV 0 arrived from trip at 2022-01-19 21:15:00. Drove: 9.682045494095707 km.
# EV 0 used 1.33 kWh of energy during the trip.
# Energy Before Trip: 8.84 kWh
# Energy After Trip: 7.51 kWh
# EV 0 arrived from trip at 2022-01-20 14:00:00. Drove: 6.969472417650714 km.
# EV 0 used 1.14 kWh of energy during the trip.
# Energy Before Trip: 57.48 kWh
# Energy After Trip: 56.34 kWh
# EV 0 arrived from trip at 2022-01-20 16:15:00. Drove: 450.5138543075367 km.
# EV 0 used 61.72 kWh of energy during the trip.
# Energy Before Trip: 56.54 kWh
# Energy After Trip: -5.18 kWh
# EV 0 arrived from trip at 2022-01-20 16:30:00. Drove: 39.1282665009322 km.
# EV 0 used 5.36 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 4.64 kWh
# EV 0 arrived from trip at 2022-01-20 18:45:00. Drove: 18.106825369794908 km.
# EV 0 used 2.97 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 54.53 kWh
# EV 0 arrived from trip at 2022-01-21 17:15:00. Drove: 11.274381901802368 km.
# EV 0 used 1.85 kWh of energy during the trip.
# Energy Before Trip: 57.02 kWh
# Energy After Trip: 55.17 kWh
# EV 0 arrived from trip at 2022-01-21 20:15:00. Drove: 0.780164822871346 km.
# EV 0 used 0.11 kWh of energy during the trip.
# Energy Before Trip: 56.60 kWh
# Energy After Trip: 56.49 kWh
# EV 0 arrived from trip at 2022-01-21 20:15:00. Drove: 28.84609422001244 km.
# EV 0 used 3.95 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 6.05 kWh
# EV 0 arrived from trip at 2022-01-22 13:00:00. Drove: 0.11302387818521263 km.
# EV 0 used 0.02 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 57.48 kWh
# EV 0 arrived from trip at 2022-01-22 17:45:00. Drove: 7.097499465506525 km.
# EV 0 used 0.97 kWh of energy during the trip.
# Energy Before Trip: 12.48 kWh
# Energy After Trip: 11.51 kWh
# EV 0 arrived from trip at 2022-01-22 23:30:00. Drove: 15.419257576134243 km.
# EV 0 used 2.11 kWh of energy during the trip.
# Energy Before Trip: 49.78 kWh
# Energy After Trip: 47.67 kWh
# EV 0 arrived from trip at 2022-01-23 13:45:00. Drove: 115.10931876942189 km.
# EV 0 used 15.77 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 41.73 kWh
# EV 0 arrived from trip at 2022-01-23 15:15:00. Drove: 41.180700111870735 km.
# EV 0 used 6.75 kWh of energy during the trip.
# Energy Before Trip: 47.18 kWh
# Energy After Trip: 40.43 kWh
# EV 0 arrived from trip at 2022-01-23 18:00:00. Drove: 126.51872919825972 km.
# EV 0 used 17.33 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: -7.33 kWh
# EV 0 arrived from trip at 2022-01-23 23:15:00. Drove: 38.498133374767015 km.
# EV 0 used 6.31 kWh of energy during the trip.
# Energy Before Trip: 50.35 kWh
# Energy After Trip: 44.04 kWh
# total_energy_charged: 321.42487530499034
# total_energy_discharged: 178.33157743437425
# total_money_spent_charging: -59.4709732741281
# total_money_earned_discharging: 34.33274228975229
# total_transformer_overload: 0.0
# total_reward: 35739.09641350604
# Iteration 7/200: Episode reward: 35739.09641350604
# Warning: No trips found for EV 0 on Sunday. Resampling...
# Warning: No trips found for EV 0 on Sunday. Resampling...
# Warning: No trips found for EV 1 on Monday. Resampling...
# Warning: No trips found for EV 1 on Friday. Resampling...
# Warning: No trips found for EV 2 on Wednesday. Resampling...
# Warning: No trips found for EV 2 on Wednesday. Resampling...
# Warning: No trips found for EV 2 on Sunday. Resampling...
# EV 0 arrived from trip at 2022-01-17 10:30:00. Drove: 16.84255827221874 km.
# EV 0 used 2.76 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 54.74 kWh
# EV 0 arrived from trip at 2022-01-17 12:45:00. Drove: 7.859660484773152 km.
# EV 0 used 1.08 kWh of energy during the trip.
# Energy Before Trip: 41.44 kWh
# Energy After Trip: 40.36 kWh
# EV 0 arrived from trip at 2022-01-17 14:15:00. Drove: 24.916263977625814 km.
# EV 0 used 4.09 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 53.41 kWh
# EV 0 arrived from trip at 2022-01-17 18:45:00. Drove: 30.958540509633295 km.
# EV 0 used 4.24 kWh of energy during the trip.
# Energy Before Trip: 51.72 kWh
# Energy After Trip: 47.48 kWh
# EV 0 arrived from trip at 2022-01-18 14:30:00. Drove: 13.928942722187701 km.
# EV 0 used 1.91 kWh of energy during the trip.
# Energy Before Trip: 56.54 kWh
# Energy After Trip: 54.63 kWh
# EV 0 arrived from trip at 2022-01-18 19:00:00. Drove: 47.661069198259774 km.
# EV 0 used 7.82 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 49.68 kWh
# EV 0 arrived from trip at 2022-01-18 19:15:00. Drove: 8.784855947793663 km.
# EV 0 used 1.20 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 8.80 kWh
# EV 0 arrived from trip at 2022-01-19 08:30:00. Drove: 19.877199390925984 km.
# EV 0 used 2.72 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 54.78 kWh
# EV 0 arrived from trip at 2022-01-19 15:00:00. Drove: 9.965105295214412 km.
# EV 0 used 1.63 kWh of energy during the trip.
# Energy Before Trip: 46.31 kWh
# Energy After Trip: 44.68 kWh
# EV 0 arrived from trip at 2022-01-19 15:30:00. Drove: 35.82256811684284 km.
# EV 0 used 4.91 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 52.59 kWh
# EV 0 arrived from trip at 2022-01-19 16:15:00. Drove: 8.471789807333748 km.
# EV 0 used 1.16 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 8.84 kWh
# EV 0 arrived from trip at 2022-01-19 21:15:00. Drove: 9.682045494095707 km.
# EV 0 used 1.33 kWh of energy during the trip.
# Energy Before Trip: 8.84 kWh
# Energy After Trip: 7.51 kWh
# EV 0 arrived from trip at 2022-01-20 07:00:00. Drove: 17.602718868862688 km.
# EV 0 used 2.41 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 7.59 kWh
# EV 0 arrived from trip at 2022-01-20 14:00:00. Drove: 80.15893491609694 km.
# EV 0 used 10.98 kWh of energy during the trip.
# Energy Before Trip: 55.10 kWh
# Energy After Trip: 44.12 kWh
# EV 0 arrived from trip at 2022-01-20 14:00:00. Drove: 6.969472417650714 km.
# EV 0 used 1.14 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 56.36 kWh
# EV 0 arrived from trip at 2022-01-20 18:45:00. Drove: 18.106825369794908 km.
# EV 0 used 2.97 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 54.53 kWh
# EV 0 arrived from trip at 2022-01-21 14:45:00. Drove: 5.731210814170289 km.
# EV 0 used 0.79 kWh of energy during the trip.
# Energy Before Trip: 53.56 kWh
# Energy After Trip: 52.77 kWh
# EV 0 arrived from trip at 2022-01-21 17:00:00. Drove: 90.09303366065878 km.
# EV 0 used 14.78 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 42.72 kWh
# EV 0 arrived from trip at 2022-01-21 23:45:00. Drove: 16.26143550031075 km.
# EV 0 used 2.23 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 7.77 kWh
# EV 0 arrived from trip at 2022-01-22 16:30:00. Drove: 23.219905593536367 km.
# EV 0 used 3.81 kWh of energy during the trip.
# Energy Before Trip: 55.18 kWh
# Energy After Trip: 51.37 kWh
# EV 0 arrived from trip at 2022-01-22 17:45:00. Drove: 7.097499465506525 km.
# EV 0 used 0.97 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 9.03 kWh
# EV 0 arrived from trip at 2022-01-22 23:30:00. Drove: 15.419257576134243 km.
# EV 0 used 2.11 kWh of energy during the trip.
# Energy Before Trip: 56.06 kWh
# Energy After Trip: 53.95 kWh
# EV 0 arrived from trip at 2022-01-23 15:15:00. Drove: 41.180700111870735 km.
# EV 0 used 6.75 kWh of energy during the trip.
# Energy Before Trip: 52.47 kWh
# Energy After Trip: 45.72 kWh
# ...
# Warning: No trips found for EV 2 on Thursday. Resampling...
# Warning: No trips found for EV 2 on Thursday. Resampling...
# EV 0 arrived from trip at 2022-01-17 09:30:00. Drove: 30.736493598508382 km.
# EV 0 used 4.21 kWh of energy during the trip.
# Energy Before Trip: 42.35 kWh
# Energy After Trip: 38.14 kWh
# EV 0 arrived from trip at 2022-01-17 12:00:00. Drove: 2.777586811684276 km.
# EV 0 used 0.38 kWh of energy during the trip.
# Energy Before Trip: 32.38 kWh
# Energy After Trip: 32.00 kWh
# EV 0 arrived from trip at 2022-01-17 13:00:00. Drove: 14.289018794282164 km.
# EV 0 used 1.96 kWh of energy during the trip.
# Energy Before Trip: 52.06 kWh
# Energy After Trip: 50.10 kWh
# EV 0 arrived from trip at 2022-01-17 21:30:00. Drove: 80.86208346799266 km.
# EV 0 used 13.26 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 44.24 kWh
# EV 0 arrived from trip at 2022-01-18 10:45:00. Drove: 1.8343875450590428 km.
# EV 0 used 0.30 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 57.20 kWh
# EV 0 arrived from trip at 2022-01-18 11:45:00. Drove: 14.62909064014915 km.
# EV 0 used 2.00 kWh of energy during the trip.
# Energy Before Trip: 22.86 kWh
# Energy After Trip: 20.86 kWh
# EV 0 arrived from trip at 2022-01-18 20:45:00. Drove: 2.2384729148539457 km.
# EV 0 used 0.31 kWh of energy during the trip.
# Energy Before Trip: 55.03 kWh
# Energy After Trip: 54.72 kWh
# EV 0 arrived from trip at 2022-01-19 13:15:00. Drove: 15.013171783716594 km.
# EV 0 used 2.46 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 55.04 kWh
# EV 0 arrived from trip at 2022-01-19 15:15:00. Drove: 15.747326886264766 km.
# EV 0 used 2.16 kWh of energy during the trip.
# Energy Before Trip: 42.42 kWh
# Energy After Trip: 40.26 kWh
# EV 0 arrived from trip at 2022-01-19 16:15:00. Drove: 64.6256532504661 km.
# EV 0 used 8.85 kWh of energy during the trip.
# Energy Before Trip: 53.18 kWh
# Energy After Trip: 44.33 kWh
# EV 0 arrived from trip at 2022-01-19 21:00:00. Drove: 13.37782628962089 km.
# EV 0 used 1.83 kWh of energy during the trip.
# Energy Before Trip: 57.29 kWh
# Energy After Trip: 55.46 kWh
# EV 0 arrived from trip at 2022-01-20 07:45:00. Drove: 13.999957725295216 km.
# EV 0 used 2.30 kWh of energy during the trip.
# Energy Before Trip: 57.48 kWh
# Energy After Trip: 55.18 kWh
# EV 0 arrived from trip at 2022-01-20 15:00:00. Drove: 4.035852641392174 km.
# EV 0 used 0.66 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 56.84 kWh
# EV 0 arrived from trip at 2022-01-20 17:00:00. Drove: 7.601605966438793 km.
# EV 0 used 1.04 kWh of energy during the trip.
# Energy Before Trip: 55.76 kWh
# Energy After Trip: 54.72 kWh
# EV 0 arrived from trip at 2022-01-20 21:00:00. Drove: 5.06507008079552 km.
# EV 0 used 0.69 kWh of energy during the trip.
# Energy Before Trip: 26.86 kWh
# Energy After Trip: 26.17 kWh
# EV 0 arrived from trip at 2022-01-21 10:30:00. Drove: 66.19998585456798 km.
# EV 0 used 9.07 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 48.43 kWh
# EV 0 arrived from trip at 2022-01-21 16:30:00. Drove: 11.441417190801737 km.
# EV 0 used 1.88 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 55.62 kWh
# EV 0 arrived from trip at 2022-01-21 18:15:00. Drove: 2.5905472964574257 km.
# EV 0 used 0.35 kWh of energy during the trip.
# Energy Before Trip: 32.80 kWh
# Energy After Trip: 32.45 kWh
# EV 0 arrived from trip at 2022-01-21 19:15:00. Drove: 13.046756345556252 km.
# EV 0 used 2.14 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 55.36 kWh
# EV 0 arrived from trip at 2022-01-21 20:00:00. Drove: 12.868718732131772 km.
# EV 0 used 1.76 kWh of energy during the trip.
# Energy Before Trip: 56.78 kWh
# Energy After Trip: 55.02 kWh
# EV 0 arrived from trip at 2022-01-22 15:00:00. Drove: 77.82444171535127 km.
# EV 0 used 10.66 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 46.84 kWh
# EV 0 arrived from trip at 2022-01-22 15:00:00. Drove: 10.389194891236798 km.
# EV 0 used 1.70 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 55.80 kWh
# EV 0 arrived from trip at 2022-01-22 17:30:00. Drove: 49.70150027346184 km.
# EV 0 used 6.81 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 3.19 kWh
# EV 0 arrived from trip at 2022-01-23 09:00:00. Drove: 23.59698525792419 km.
# EV 0 used 3.23 kWh of energy during the trip.
# Energy Before Trip: 23.92 kWh
# Energy After Trip: 20.69 kWh
# EV 0 arrived from trip at 2022-01-23 11:00:00. Drove: 4.6029724549409545 km.
# EV 0 used 0.75 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 56.75 kWh
# EV 0 arrived from trip at 2022-01-23 16:00:00. Drove: 18.17083889372281 km.
# EV 0 used 2.49 kWh of energy during the trip.
# Energy Before Trip: 44.04 kWh
# Energy After Trip: 41.55 kWh
# total_energy_charged: 779.360661803266
# total_energy_discharged: 666.2337507715014
# total_money_spent_charging: -146.72214924134892
# total_money_earned_discharging: 122.24257724308357
# total_transformer_overload: 0.0
# total_reward: 90140.92395249878
# Iteration 197/200: Episode reward: 90140.92395249878
# Warning: No trips found for EV 0 on Monday. Resampling...
# Warning: No trips found for EV 0 on Monday. Resampling...
# Warning: No trips found for EV 0 on Friday. Resampling...
# Warning: No trips found for EV 0 on Friday. Resampling...
# Warning: No trips found for EV 0 on Sunday. Resampling...
# Warning: No trips found for EV 1 on Tuesday. Resampling...
# Warning: No trips found for EV 2 on Tuesday. Resampling...
# Warning: No trips found for EV 2 on Wednesday. Resampling...
# Warning: No trips found for EV 2 on Wednesday. Resampling...
# Warning: No trips found for EV 2 on Thursday. Resampling...
# Warning: No trips found for EV 2 on Thursday. Resampling...
# EV 0 arrived from trip at 2022-01-17 10:45:00. Drove: 26.589617501553768 km.
# EV 0 used 3.64 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 53.86 kWh
# EV 0 arrived from trip at 2022-01-17 13:30:00. Drove: 7.5675987818520785 km.
# EV 0 used 1.24 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 56.26 kWh
# EV 0 arrived from trip at 2022-01-17 16:30:00. Drove: 41.25371553760094 km.
# EV 0 used 5.65 kWh of energy during the trip.
# Energy Before Trip: 25.21 kWh
# Energy After Trip: 19.56 kWh
# EV 0 arrived from trip at 2022-01-18 11:00:00. Drove: 33.87115584835301 km.
# EV 0 used 5.55 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 51.95 kWh
# EV 0 arrived from trip at 2022-01-18 11:45:00. Drove: 14.62909064014915 km.
# EV 0 used 2.00 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 8.00 kWh
# EV 0 arrived from trip at 2022-01-18 14:30:00. Drove: 44.16533066500937 km.
# EV 0 used 6.05 kWh of energy during the trip.
# Energy Before Trip: 53.45 kWh
# Energy After Trip: 47.40 kWh
# EV 0 arrived from trip at 2022-01-19 15:15:00. Drove: 10.478213697949029 km.
# EV 0 used 1.44 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 56.06 kWh
# EV 0 arrived from trip at 2022-01-19 18:15:00. Drove: 21.771599614667497 km.
# EV 0 used 2.98 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 7.02 kWh
# EV 0 arrived from trip at 2022-01-19 18:15:00. Drove: 76.50216236171545 km.
# EV 0 used 12.55 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 44.95 kWh
# EV 0 arrived from trip at 2022-01-20 07:45:00. Drove: 13.999957725295216 km.
# EV 0 used 2.30 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 55.20 kWh
# EV 0 arrived from trip at 2022-01-20 12:45:00. Drove: 23.107881926662554 km.
# EV 0 used 3.17 kWh of energy during the trip.
# Energy Before Trip: 19.92 kWh
# Energy After Trip: 16.75 kWh
# EV 0 arrived from trip at 2022-01-20 15:00:00. Drove: 4.035852641392174 km.
# EV 0 used 0.66 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 56.84 kWh
# EV 0 arrived from trip at 2022-01-20 18:30:00. Drove: 18.390885382224994 km.
# EV 0 used 2.52 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 54.98 kWh
# EV 0 arrived from trip at 2022-01-21 10:30:00. Drove: 66.19998585456798 km.
# EV 0 used 9.07 kWh of energy during the trip.
# Energy Before Trip: 46.01 kWh
# Energy After Trip: 36.94 kWh
# EV 0 arrived from trip at 2022-01-21 16:30:00. Drove: 41.330731808576815 km.
# EV 0 used 6.78 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 50.72 kWh
# EV 0 arrived from trip at 2022-01-21 20:00:00. Drove: 12.868718732131772 km.
# EV 0 used 1.76 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 55.74 kWh
# EV 0 arrived from trip at 2022-01-21 20:30:00. Drove: 11.316390776880052 km.
# EV 0 used 1.55 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 8.45 kWh
# EV 0 arrived from trip at 2022-01-22 12:30:00. Drove: 0.9592026476072063 km.
# EV 0 used 0.13 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 57.37 kWh
# EV 0 arrived from trip at 2022-01-22 17:30:00. Drove: 49.70150027346184 km.
# EV 0 used 8.15 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 49.35 kWh
# EV 0 arrived from trip at 2022-01-22 22:00:00. Drove: 110.07325481665632 km.
# EV 0 used 15.08 kWh of energy during the trip.
# Energy Before Trip: 22.01 kWh
# Energy After Trip: 6.93 kWh
# EV 0 arrived from trip at 2022-01-23 12:45:00. Drove: 11.287384648850216 km.
# EV 0 used 1.85 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 55.65 kWh
# EV 0 arrived from trip at 2022-01-23 16:00:00. Drove: 18.17083889372281 km.
# EV 0 used 2.49 kWh of energy during the trip.
# Energy Before Trip: 47.64 kWh
# Energy After Trip: 45.15 kWh
# EV 0 arrived from trip at 2022-01-23 22:45:00. Drove: 54.58853274083272 km.
# EV 0 used 7.48 kWh of energy during the trip.
# Energy Before Trip: 10.00 kWh
# Energy After Trip: 2.52 kWh
# total_energy_charged: 790.2058308500627
# total_energy_discharged: 670.0547313739054
# total_money_spent_charging: -143.04714122481036
# total_money_earned_discharging: 125.98339981806951
# total_transformer_overload: 0.0
# total_reward: 94278.16470782163
# Iteration 198/200: Episode reward: 94278.16470782163
# Warning: No trips found for EV 0 on Monday. Resampling...
# Warning: No trips found for EV 0 on Friday. Resampling...
# Warning: No trips found for EV 2 on Wednesday. Resampling...
# Warning: No trips found for EV 2 on Thursday. Resampling...
# Warning: No trips found for EV 2 on Sunday. Resampling...
# EV 0 arrived from trip at 2022-01-17 11:00:00. Drove: 51.29583710379114 km.
# EV 0 used 8.41 kWh of energy during the trip.
# Energy Before Trip: 56.25 kWh
# Energy After Trip: 47.84 kWh
# EV 0 arrived from trip at 2022-01-17 12:15:00. Drove: 4.078861727781227 km.
# EV 0 used 0.56 kWh of energy during the trip.
# Energy Before Trip: 40.21 kWh
# Energy After Trip: 39.65 kWh
# EV 0 arrived from trip at 2022-01-17 16:30:00. Drove: 41.25371553760094 km.
# EV 0 used 5.65 kWh of energy during the trip.
# Energy Before Trip: 36.56 kWh
# Energy After Trip: 30.91 kWh
# EV 0 arrived from trip at 2022-01-17 17:30:00. Drove: 20.223272504661278 km.
# EV 0 used 3.32 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 54.18 kWh
# EV 0 arrived from trip at 2022-01-18 09:30:00. Drove: 19.726167482908636 km.
# EV 0 used 2.70 kWh of energy during the trip.
# Energy Before Trip: 43.07 kWh
# Energy After Trip: 40.37 kWh
# EV 0 arrived from trip at 2022-01-18 10:00:00. Drove: 24.623202063393407 km.
# EV 0 used 3.37 kWh of energy during the trip.
# Energy Before Trip: 40.37 kWh
# Energy After Trip: 36.99 kWh
# EV 0 arrived from trip at 2022-01-18 11:00:00. Drove: 33.87115584835301 km.
# EV 0 used 5.55 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 51.95 kWh
# EV 0 arrived from trip at 2022-01-18 11:45:00. Drove: 14.62909064014915 km.
# EV 0 used 2.00 kWh of energy during the trip.
# Energy Before Trip: 51.87 kWh
# Energy After Trip: 49.87 kWh
# EV 0 arrived from trip at 2022-01-18 21:30:00. Drove: 10.448207358607837 km.
# EV 0 used 1.43 kWh of energy during the trip.
# Energy Before Trip: 52.46 kWh
# Energy After Trip: 51.03 kWh
# EV 0 arrived from trip at 2022-01-19 10:15:00. Drove: 5.00805803604724 km.
# EV 0 used 0.69 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 56.81 kWh
# EV 0 arrived from trip at 2022-01-19 12:45:00. Drove: 3.2506867619639523 km.
# EV 0 used 0.45 kWh of energy during the trip.
# Energy Before Trip: 54.29 kWh
# Energy After Trip: 53.84 kWh
# EV 0 arrived from trip at 2022-01-19 18:00:00. Drove: 36.93380288377874 km.
# EV 0 used 5.06 kWh of energy during the trip.
# Energy Before Trip: 13.04 kWh
# Energy After Trip: 7.98 kWh
# EV 0 arrived from trip at 2022-01-19 18:15:00. Drove: 76.50216236171545 km.
# EV 0 used 12.55 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 44.95 kWh
# EV 0 arrived from trip at 2022-01-20 07:45:00. Drove: 13.999957725295216 km.
# EV 0 used 2.30 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 55.20 kWh
# EV 0 arrived from trip at 2022-01-20 12:45:00. Drove: 14.088976532007461 km.
# EV 0 used 1.93 kWh of energy during the trip.
# Energy Before Trip: 45.27 kWh
# Energy After Trip: 43.34 kWh
# EV 0 arrived from trip at 2022-01-20 15:00:00. Drove: 6.554384723430699 km.
# EV 0 used 0.90 kWh of energy during the trip.
# Energy Before Trip: 25.18 kWh
# Energy After Trip: 24.28 kWh
# EV 0 arrived from trip at 2022-01-20 15:00:00. Drove: 4.035852641392174 km.
# EV 0 used 0.66 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 56.84 kWh
# EV 0 arrived from trip at 2022-01-21 10:30:00. Drove: 66.19998585456798 km.
# EV 0 used 9.07 kWh of energy during the trip.
# Energy Before Trip: 55.27 kWh
# Energy After Trip: 46.20 kWh
# EV 0 arrived from trip at 2022-01-21 13:00:00. Drove: 6.9644713610938345 km.
# EV 0 used 1.14 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 56.36 kWh
# EV 0 arrived from trip at 2022-01-21 14:00:00. Drove: 11.432415288999387 km.
# EV 0 used 1.57 kWh of energy during the trip.
# Energy Before Trip: 37.02 kWh
# Energy After Trip: 35.45 kWh
# EV 0 arrived from trip at 2022-01-21 20:00:00. Drove: 12.868718732131772 km.
# EV 0 used 1.76 kWh of energy during the trip.
# Energy Before Trip: 55.03 kWh
# Energy After Trip: 53.27 kWh
# EV 0 arrived from trip at 2022-01-21 20:30:00. Drove: 14.464055773772536 km.
# EV 0 used 2.37 kWh of energy during the trip.
# Energy Before Trip: 56.74 kWh
# Energy After Trip: 54.37 kWh
# EV 0 arrived from trip at 2022-01-22 16:30:00. Drove: 23.219905593536367 km.
# EV 0 used 3.18 kWh of energy during the trip.
# Energy Before Trip: 51.02 kWh
# Energy After Trip: 47.84 kWh
# EV 0 arrived from trip at 2022-01-22 18:00:00. Drove: 63.58143264139217 km.
# EV 0 used 8.71 kWh of energy during the trip.
# Energy Before Trip: 27.36 kWh
# Energy After Trip: 18.65 kWh
# EV 0 arrived from trip at 2022-01-22 20:00:00. Drove: 23.35593433188317 km.
# EV 0 used 3.83 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 53.67 kWh
# EV 0 arrived from trip at 2022-01-23 14:30:00. Drove: 339.90381036668816 km.
# EV 0 used 46.57 kWh of energy during the trip.
# Energy Before Trip: 27.77 kWh
# Energy After Trip: -18.80 kWh
# EV 0 arrived from trip at 2022-01-23 16:00:00. Drove: 18.17083889372281 km.
# EV 0 used 2.49 kWh of energy during the trip.
# Energy Before Trip: 56.48 kWh
# Energy After Trip: 53.99 kWh
# EV 0 arrived from trip at 2022-01-23 19:00:00. Drove: 13.860928353014295 km.
# EV 0 used 2.27 kWh of energy during the trip.
# Energy Before Trip: 57.50 kWh
# Energy After Trip: 55.23 kWh
# total_energy_charged: 745.1053040191467
# total_energy_discharged: 621.6103574651202
# total_money_spent_charging: -140.96580541027697
# total_money_earned_discharging: 117.78421082638435
# total_transformer_overload: 0.0
# total_reward: 96585.71764896848
# Iteration 199/200: Episode reward: 96585.71764896848
# Complete

# %% [markdown]
# Plot the total rewards per episode to see how the agent improved during training.

# %%
#Plot the rewards
from matplotlib import pyplot as plt

plt.plot(episode_rewards)
plt.ylabel('Episode reward')
plt.xlabel('Episode')
plt.show()

# %% [markdown]
# Plot other metrics from the info dictionary returned by the environment. For example, the number of times the agent charged or discharged the EVs.

# %%
#plot episode stats
import pandas as pd
episode_stats = pd.DataFrame(episode_stats)
#Select only the columns we want to plot
print(episode_stats.columns)
episode_stats = episode_stats[['total_money_spent','total_money_earned']]

#plot
episode_stats.plot(subplots=True, figsize=(10,10))
# Out:
# Index(['total_money_spent', 'total_money_earned', 'total_invalid_penalty',
#        'transformer_overloaded', 'current_step'],
#       dtype='object')
# array([<Axes: >, <Axes: >], dtype=object)

# %%
torch.save(policy_net.state_dict(), "policy_net0.pt")
torch.save(target_net.state_dict(), "target_net0.pt")

# %%
torch.save(optimizer.state_dict, "optimizer0.pt")
